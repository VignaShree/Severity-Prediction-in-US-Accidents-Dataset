# %%
import pandas as pd
import numpy as np
import nltk
from nltk.tokenize import sent_tokenize,word_tokenize
from nltk.corpus import stopwords
from nltk.book import FreqDist
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
CA_accidents = pd.read_csv('CAAccidents.csv')

# %%
CA_accidents.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 663204 entries, 0 to 663203
# Data columns (total 50 columns):
# Unnamed: 0               663204 non-null int64
# ID                       663204 non-null object
# Source                   663204 non-null object
# TMC                      449296 non-null float64
# Severity                 663204 non-null int64
# Start_Time               663204 non-null object
# End_Time                 663204 non-null object
# Start_Lat                663204 non-null float64
# Start_Lng                663204 non-null float64
# End_Lat                  213908 non-null float64
# End_Lng                  213908 non-null float64
# Distance(mi)             663204 non-null float64
# Description              663204 non-null object
# Number                   139891 non-null float64
# Street                   663204 non-null object
# Side                     663204 non-null object
# City                     663198 non-null object
# County                   663204 non-null object
# State                    663204 non-null object
# Zipcode                  662999 non-null object
# Country                  663204 non-null object
# Timezone                 662999 non-null object
# Airport_Code             662991 non-null object
# Weather_Timestamp        653807 non-null object
# Temperature(F)           648079 non-null float64
# Wind_Chill(F)            191385 non-null float64
# Humidity(%)              646890 non-null float64
# Pressure(in)             651962 non-null float64
# Visibility(mi)           650008 non-null float64
# Wind_Direction           651056 non-null object
# Wind_Speed(mph)          534398 non-null float64
# Precipitation(in)        195589 non-null float64
# Weather_Condition        650323 non-null object
# Amenity                  663204 non-null bool
# Bump                     663204 non-null bool
# Crossing                 663204 non-null bool
# Give_Way                 663204 non-null bool
# Junction                 663204 non-null bool
# No_Exit                  663204 non-null bool
# Railway                  663204 non-null bool
# Roundabout               663204 non-null bool
# Station                  663204 non-null bool
# Stop                     663204 non-null bool
# Traffic_Calming          663204 non-null bool
# Traffic_Signal           663204 non-null bool
# Turning_Loop             663204 non-null bool
# Sunrise_Sunset           663198 non-null object
# Civil_Twilight           663198 non-null object
# Nautical_Twilight        663198 non-null object
# Astronomical_Twilight    663198 non-null object
# dtypes: bool(13), float64(14), int64(2), object(21)
# memory usage: 195.4+ MB

# %%
## converting a list to text###
text = CA_accidents['Description']
# Function to convert   
def listToString(s):  
    
    # initialize an empty string 
    str1 = ""  
    
    # traverse in the string   
    for ele in s:  
        str1 += ele   
    
    # return string   
    return str1  
        
        
# Driver code     
text = (listToString(text))

# %%
# word Tokenization
words = word_tokenize(text)
words
# Out:
# ['Right',
#  'hand',
#  'shoulder',
#  'blocked',
#  'due',
#  'to',
#  'accident',
#  'on',
#  'I-80',
#  'Westbound',
#  'at',
#  'Magazine',
#  'St.Accident',
#  'on',
#  'I-880',
#  'Northbound',
#  'at',
#  'Exit',
#  '26',
#  'Tennyson',
#  'Rd.Right',
#  'lane',
#  'blocked',
#  'due',
#  'to',
#  'accident',
#  'on',
#  'CA-24',
#  'Westbound',
#  'at',
#  'I-680.',
#  '#',
#  '4',
#  '&',
#  'amp',
#  ';',
#  'HOV',
#  'lane',
#  'blocked',
#  'due',
#  'to',
#  'accident',
#  'on',
#  'I-280',
#  'Northbound',
#  'before',
#  'Exit',
#  '11',
#  'De',
#  'Anza',
#  'Blvd.Right',
#  'hand',
#  'shoulder',
#  'blocked',
#  'due',
#  'to',
#  'accident',
#  'on',
#  'CA-85',
#  'Northbound',
#  'at',
#  'Exit',
#  '8',
#  'Camden',
#  'Ave.Accident',
#  'on',
#  'I-580',
#  'Westbound',
#  'near',
#  'I-580',
#  'Exit',
#  '45',
#  '/',
#  'Dougherty',
#  'Rd.',
#  '#',
#  '1',
#  'lane',
#  'blocked',
#  'due',
#  'to',
#  'accident',
#  'on',
#  'I-280',
#  'Southbound',
#  'at',
#  '10th',
#  'St.Accident',
#  'on',
#  'I-280',
#  'Northbound',
#  'at',
#  'Geneva',
#  'Ave.Right',
#  'hand',
#  'shoulder',
#  'blocked',
#  'due',
#  'to',
#  'accident',
#  'on',
#  'CA-24',
#  'Westbound',
#  'near',
#  'Wilder',
#  'Rd.Left',
#  'lane',
#  'blocked',
#  'due',
#  'to',
#  'accident',
#  'on',
#  'I-580',
#  'Westbound',
#  'at',
#  'Exit',
#  '51',
#  'Isabel',
#  'Ave.Right',
#  'hand',
#  'shoulder',
#  'blocked',
#  'due',
#  'to',
#  'accident',
#  'on',
#  'US-101',
#  'Northbound',
#  'at',
#  'Exit',
#  '481A',
#  'Sierra',
#  'Ave.Accident',
#  'on',
#  'CA-4',
#  'Westbound',
#  'at',
#  'CA-242.',
#  '#',
#  '4',
#  '&',
#  'amp',
#  ';',
#  '#',
#  '5',
#  'lane',
#  'blocked',
#  'due',
#  'to',
#  'accident',
#  'on',
#  'I-580',
#  'Westbound',
#  'at',
#  'County',
#  'Hwy-J2',
#  'Livermore',
#  'Ave.',
#  '#',
#  '1',
#  'lane',
#  'blocked',
#  'due',
#  'to',
#  'accident',
#  'on',
#  'US-101',
#  'Northbound',
#  'before',
#  'Fair',
#  'Oaks',
#  'Ave.',
#  '#',
#  '2',
#  'lane',
#  'blocked',
#  'due',
#  'to',
#  'accident',
#  'on',
#  'I-580',
#  'Westbound',
#  'at',
#  'Exit',
#  '47',
#  '/',
#  'Tassajara',
#  'Rd.',
#  '#',
#  '1',
#  'lane',
#  'blocked',
#  'due',
#  'to',
#  'accident',
#  'on',
#  'Power',
#  'Inn',
#  'Rd',
#  'Northbound',
#  'at',
#  'Gerber',
#  'Rd.Multi-vehicle',
#  'accident',
#  'on',
#  'I-80',
#  'Westbound',
#  'at',
#  'Exit',
#  '98',
#  'County',
#  'Hwy-E14',
#  'Greenback',
#  'Ln',
#  '.',
#  'On',
#  'the',
#  'median.Accident',
#  'on',
#  'US-101',
#  'Northbound',
#  'at',
#  'Exit',
#  '394',
#  '/',
#  'County',
#  'Hwy-G2',
#  'Lawrence',
#  'Expy.Accident',
#  'a',
#  'school',
#  'bus',
#  'involved',
#  'on',
#  '37th',
#  'Ave',
#  'near',
#  'International',
#  'Blvd.Right',
#  'hand',
#  'shoulder',
#  'blocked',
#  'due',
#  'to',
#  'accident',
#  'on',
#  'CA-237',
#  'Westbound',
#  'near',
#  'Exit',
#  '6',
#  'Great',
#  'America',
#  'Pkwy.',
#  '#',
#  '2',
#  'lane',
#  'blocked',
#  'due',
#  'to',
#  'accident',
#  'on',
#  'I-880',
#  'Southbound',
#  'at',
#  'Exit',
#  '5',
#  '/',
#  'Brokaw',
#  'Rd.Accident',
#  'on',
#  'I-580',
#  'Westbound',
#  'at',
#  'Exit',
#  '48',
#  '/',
#  'El',
#  'Charro',
#  'Rd.Accident',
#  'on',
#  'US-101',
#  'Northbound',
#  'at',
#  'Exit',
#  '366',
#  'Dunne',
#  'Ave.Right',
#  'hand',
#  'shoulder',
#  'blocked',
#  'due',
#  'to',
#  'accident',
#  'on',
#  'US-101',
#  'Northbound',
#  'at',
#  'Exit',
#  '479',
#  'Railroad',
#  'Ave.Accident',
#  'on',
#  'I-680',
#  'Northbound',
#  'at',
#  'Toll',
#  'Plaza.Right',
#  'hand',
#  'shoulder',
#  'blocked',
#  'due',
#  'to',
#  'accident',
#  'on',
#  'US-101',
#  'Southbound',
#  'after',
#  'Exit',
#  '472A',
#  'Kastania',
#  'Rd.',
#  '#',
#  '2',
#  'lane',
#  'blocked',
#  'due',
#  'to',
#  'accident',
#  'on',
#  'US-101',
#  'Northbound',
#  'at',
#  'Exit',
#  '422',
#  'McDonnell',
#  'Rd.Accident',
#  'on',
#  'I-80',
#  'Bus',
#  'Capital',
#  'City',
#  'Fwy',
#  'Westbound',
#  'at',
#  'CA-51.Accident',
#  'on',
#  'I-880',
#  'Southbound',
#  'at',
#  'I-880',
#  'Exit',
#  '29',
#  '/',
#  'A',
#  'St.Accident',
#  'on',
#  'I-580',
#  'Westbound',
#  'at',
#  'County',
#  'Hwy-J2',
#  'Livermore',
#  'Ave.Accident',
#  'on',
#  'US-101',
#  'Northbound',
#  'after',
#  'Windsor',
#  'River',
#  'Rd.Accident',
#  'on',
#  'I-680',
#  'Northbound',
#  'at',
#  'Exits',
#  '42A',
#  '42B',
#  'Stone',
#  'Valley',
#  'Rd.Accident',
#  'on',
#  'US-101',
#  'Northbound',
#  'before',
#  'Exit',
#  '365',
#  'Tennant',
#  'Ave.Accident',
#  'on',
#  'US-101',
#  'Northbound',
#  'at',
#  'Exit',
#  '362',
#  'San',
#  'Martin',
#  'Ave.Accident',
#  'on',
#  'US-101',
#  'Northbound',
#  'before',
#  'US-101',
#  'Exit',
#  '503',
#  '/',
#  'Healdsburg',
#  'Ave.',
#  '#',
#  '1',
#  'lane',
#  'blocked',
#  'due',
#  'to',
#  'accident',
#  'on',
#  'US-101',
#  'Northbound',
#  'near',
#  'Exit',
#  '429A',
#  'Harney',
#  'Way.Right',
#  'hand',
#  'shoulder',
#  'blocked',
#  'due',
#  'to',
#  'accident',
#  'on',
#  'US-101',
#  'Northbound',
#  'at',
#  'US-101',
#  'Exit',
#  '402',
#  '/',
#  'Embarcadero',
#  'Rd.',
#  '#',
#  '1',
#  'lane',
#  'blocked',
#  'due',
#  'to',
#  'accident',
#  'on',
#  'US-101',
#  'Southbound',
#  'at',
#  'Silver',
#  'Ave.Slow',
#  'lane',
#  'blocked',
#  'due',
#  'to',
#  'accident',
#  'on',
#  'US-101',
#  'Southbound',
#  'at',
#  'Exit',
#  '432',
#  '/',
#  'Cesar',
#  'Chavez.',
#  '#',
#  '1',
#  'lane',
#  'blocked',
#  'due',
#  'to',
#  'accident',
#  'on',
#  'I-880',
#  'Southbound',
#  'before',
#  'Dixon',
#  'Landing',
#  'Rd.Right',
#  'hand',
#  'shoulder',
#  'blocked',
#  'due',
#  'to',
#  'accident',
#  'on',
#  'I-880',
#  'Southbound',
#  'at',
#  'Exit',
#  '7',
#  '/',
#  'County',
#  'Hwy-G4',
#  'Montague',
#  'Expy.Accident',
#  'on',
#  'I-80',
#  'Eastbound',
#  'at',
#  'Exit',
#  '78',
#  'Chiles',
#  'Rd.Accident',
#  'on',
#  'I-80',
#  'Westbound',
#  'at',
#  'Exits',
#  '8A',
#  '8B',
#  'I-880.Accident',
#  'on',
#  'I-580',
#  'Westbound',
#  'at',
#  'Exit',
#  '22B',
#  'Beaumont',
#  'Ave.Accident',
#  'on',
#  'I-880',
#  'Southbound',
#  'at',
#  'I-280.Accident',
#  'on',
#  'CA-99',
#  'Southbound',
#  'at',
#  'CA-99',
#  'Exit',
#  '283',
#  '/',
#  'Eschinger',
#  'Rd',
#  '.',
#  'On',
#  'exit',
#  'ramp.Very',
#  'slow',
#  'traffic',
#  'and',
#  'shoulder',
#  'blocked',
#  'on',
#  'exit',
#  'ramp',
#  'due',
#  'to',
#  'accident',
#  'on',
#  'I-80',
#  'Eastbound',
#  'at',
#  'I-80',
#  'Exit',
#  '75',
#  '/',
#  'Mace',
#  'Blvd.Accident',
#  'on',
#  'Marconi',
#  'Ave',
#  'near',
#  'Fulton',
#  'Ave.Accident',
#  'on',
#  'CA-92',
#  'San',
#  'Mateo',
#  'Rd',
#  'Westbound',
#  'at',
#  'Pilarcitos',
#  'Creek',
#  'Rd.Accident',
#  'on',
#  'US-101',
#  'Southbound',
#  'at',
#  'Exits',
#  '404A',
#  '404B',
#  'CA-114',
#  'Willow',
#  'Rd.Slow',
#  'traffic',
#  'due',
#  'to',
#  'accident',
#  'on',
#  'Calvine',
#  'Rd',
#  'both',
#  'ways',
#  'at',
#  'Elk',
#  'Grove',
#  'Florin',
#  'Rd.Accident',
#  'on',
#  'I-580',
#  'Westbound',
#  'at',
#  'Exit',
#  '63',
#  'Grant',
#  'Line',
#  'Rd.Accident',
#  'on',
#  'Coyle',
#  'Ave',
#  'Westbound',
#  'near',
#  'St',
#  'Charles',
#  'Dr.Accident',
#  'on',
#  'I-880',
#  'Southbound',
#  'at',
#  'Exit',
#  '40',
#  '16th',
#  'Ave.Accident',
#  'on',
#  'Auburn',
#  'Folsom',
#  'Rd',
#  'Southbound',
#  'near',
#  'Moss',
#  'Ln.Accident',
#  'on',
#  'I-880',
#  'Southbound',
#  'at',
#  'Exit',
#  '24',
#  'Whipple',
#  'Rd.Very',
#  'slow',
#  'traffic',
#  'due',
#  'to',
#  'accident',
#  'on',
#  'I-80',
#  'Eastbound',
#  'near',
#  'Exit',
#  '73',
#  'Olive',
#  'Dr.Accident',
#  'on',
#  'Concord',
#  'Ave',
#  'at',
#  'Contra',
#  'Costa',
#  'Blvd.Accident',
#  'on',
#  'US-101',
#  'Southbound',
#  'at',
#  'Exits',
#  '385A',
#  '385B',
#  'I-680.Accident',
#  'on',
#  'US-101',
#  'Northbound',
#  'at',
#  'Exit',
#  '414B',
#  'CA-92.Accident',
#  'on',
#  'I-280',
#  'Northbound',
#  'at',
#  'Exit',
#  '53',
#  'Alemany',
#  'Blvd.Accident',
#  'on',
#  'CA-24',
#  'Westbound',
#  'at',
#  'Exit',
#  '6',
#  'Caldecott',
#  'Ln.Accident',
#  'on',
#  'CA-242',
#  'Southbound',
#  'at',
#  'Exit',
#  '2',
#  'Grant',
#  'St.Slow',
#  'traffic',
#  'due',
#  'to',
#  'accident',
#  'on',
#  'White',
#  'Rock',
#  'Rd',
#  'Eastbound',
#  'at',
#  'County',
#  'Hwy-E2',
#  'Sunrise',
#  'Blvd.Accident',
#  'on',
#  'CA-49',
#  'at',
#  'Tyler',
#  'Foote',
#  'Rd.Accident',
#  'on',
#  'Gerber',
#  'Rd',
#  'at',
#  'Reese',
#  'Rd.Accident',
#  'on',
#  'US-101',
#  'Southbound',
#  'at',
#  'Exit',
#  '403',
#  'Donohoe',
#  'St.Accident',
#  'on',
#  'I-80',
#  'Westbound',
#  'at',
#  'Exit',
#  '59',
#  'Meridian',
#  'Rd.Slow',
#  'traffic',
#  'due',
#  'to',
#  'accident',
#  'on',
#  'Douglas',
#  'Blvd',
#  'Southbound',
#  'near',
#  'Eureka',
#  'Rd.Accident',
#  'on',
#  'Isleton',
#  'Rd',
#  'at',
#  'Andrus',
#  'Island',
#  'Rd.Queueing',
#  'traffic',
#  'due',
#  'to',
#  'accident',
#  'on',
#  'I-5',
#  'Southbound',
#  'at',
#  'Exit',
#  '528',
#  'Airport',
#  'Blvd.Accident',
#  'on',
#  'US-50',
#  'Westbound',
#  'at',
#  'Exit',
#  '13',
#  'Bradshaw',
#  'Rd.Lane',
#  'blocked',
#  'on',
#  'exit',
#  'ramp',
#  'due',
#  'to',
#  'accident',
#  'on',
#  'CA-65',
#  'Northbound',
#  'at',
#  'Exit',
#  '313',
#  'Twelve',
#  'Bridges',
#  'Dr.Lane',
#  'closed',
#  'on',
#  'exit',
#  'ramp',
#  'due',
#  'to',
#  'accident',
#  'on',
#  'I-5',
#  'Northbound',
#  'at',
#  'Exits',
#  '518',
#  '519A',
#  'CA-99',
#  'CA-16.Accident',
#  'on',
#  'Pleasant',
#  'Valley',
#  'Rd',
#  'at',
#  'Hinman',
#  'Aly.Accident',
#  'on',
#  'US-101',
#  'Northbound',
#  'at',
#  'Exits',
#  '449',
#  '449A',
#  'Tamalpais',
#  'Dr.Accident',
#  'on',
#  'I-880',
#  'Southbound',
#  'at',
#  'Exit',
#  '31B',
#  'Washington',
#  'Ave.Accident',
#  'on',
#  'I-680',
#  'Northbound',
#  'at',
#  'Exit',
#  '36',
#  'Crow',
#  'Canyon',
#  'Rd.Accident',
#  'on',
#  'CA-17',
#  'Southbound',
#  'at',
#  'Exits',
#  '21',
#  '22',
#  'Lark',
#  'Ave.Lane',
#  'blocked',
#  'due',
#  'to',
#  'accident',
#  'on',
#  'I-580',
#  'Eastbound',
#  'at',
#  'Exit',
#  '45',
#  'Hopyard',
#  'Rd.Accident',
#  'on',
#  'US-101',
#  'Golden',
#  'Gate',
#  'Brg',
#  'Southbound',
#  'at',
#  'Exit',
#  '439',
#  'Transit',
#  'Transfer',
#  'Facility.Accident',
#  'on',
#  'I-580',
#  'Eastbound',
#  'at',
#  'Exit',
#  '36',
#  'Redwood',
#  'Rd.Two',
#  'lanes',
#  'blocked',
#  'due',
#  'to',
#  'accident',
#  'on',
#  'I-205',
#  'Westbound',
#  'at',
#  'I-5.Accident',
#  'on',
#  'I-580',
#  'Eastbound',
#  'at',
#  'Exit',
#  '51',
#  'Isabel',
#  'Ave.Right',
#  'hand',
#  'shoulder',
#  'blocked',
#  'due',
#  'to',
#  'accident',
#  'on',
#  'I-5',
#  'Northbound',
#  'at',
#  'Exit',
#  '471',
#  'Charter',
#  'Way.Lane',
#  'blocked',
#  'due',
#  'to',
#  'accident',
#  'on',
#  'US-101',
#  'Main',
#  'St',
#  'Northbound',
#  'at',
#  'Mendocino',
#  'Ave.Accident',
#  'on',
#  'US-50',
#  'Eastbound',
#  'at',
#  'Exit',
#  '7',
#  'Stockton',
#  'Blvd.Accident',
#  'on',
#  'I-80',
#  'Eastbound',
#  'at',
#  'Exits',
#  '103',
#  '103A',
#  '103B',
#  'Sunrise',
#  'Ave.Accident',
#  'on',
#  'I-80',
#  'Eastbound',
#  'at',
#  'Exits',
#  '103',
#  '103A',
#  '103B',
#  'Sunrise',
#  'Ave.Accident',
#  'on',
#  'County',
#  'Hwy-E3',
#  'Sierra',
#  'College',
#  'Blvd',
#  'at',
#  'Douglas',
#  'Blvd.Accident',
#  'on',
#  'US-101',
#  'Northbound',
#  'at',
#  'Exit',
#  '492',
#  'Mendocino',
#  'Ave.Accident',
#  'on',
#  'I-280',
#  'Southbound',
#  'at',
#  'Exit',
#  '16',
#  'El',
#  'Monte',
#  'Rd.Accident',
#  'on',
#  'I-280',
#  'Northbound',
#  'at',
#  'Exits',
#  '4',
#  '5A',
#  'Parkmoor',
#  'Ave.Accident',
#  'on',
#  'Martin',
#  'Dr',
#  'Eastbound',
#  'at',
#  'Ellison',
#  ...]

# %%
# Removing Punctuations
words = [word for word in words if word.isalpha()]
## Converting to lowercase
words = [x.lower() for x in words]

# %%
filter_sentence = []
stop_words = set(stopwords.words('english'))
# Remove stop words
for w in words:
    if w not in stop_words:
        filter_sentence.append(w)

# %%
nltk.download('wordnet')
#Lemmaitizer
lemmatizer = WordNetLemmatizer()
filter_sentence = [lemmatizer.lemmatize(word) for word in filter_sentence]
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\19175\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\wordnet.zip.

# %%
# Top 25 words
wordCount = {}
for word in filter_sentence:
    if word not in wordCount:
        wordCount[word] = 1
    else:
        wordCount[word]+= 1

# %%
# Top 200 words
frequency = nltk.FreqDist(filter_sentence)
print(frequency.most_common(200))
# Out:
# [('exit', 264703), ('accident', 258055), ('due', 242184), ('blocked', 233800), ('lane', 149338), ('northbound', 108843), ('southbound', 105328), ('shoulder', 76596), ('westbound', 76514), ('rd', 75100), ('hand', 71972), ('eastbound', 70439), ('ave', 63348), ('blvd', 44582), ('near', 39842), ('st', 36043), ('ramp', 20325), ('canyon', 16379), ('fwy', 14975), ('way', 14624), ('dr', 13838), ('valley', 12828), ('hwy', 12790), ('right', 12124), ('county', 11824), ('san', 11531), ('road', 11029), ('la', 9096), ('closed', 9056), ('left', 8211), ('el', 7869), ('traffic', 7449), ('santa', 6775), ('hill', 5735), ('beach', 5133), ('camino', 4953), ('entry', 4929), ('oak', 4877), ('creek', 4617), ('main', 4559), ('del', 4285), ('mountain', 4281), ('center', 4275), ('central', 4209), ('washington', 4072), ('avenue', 4061), ('grand', 3877), ('city', 3847), ('lake', 3737), ('old', 3707), ('vista', 3610), ('sigalert', 3446), ('pkwy', 3387), ('sierra', 3385), ('river', 3319), ('mission', 3311), ('spring', 3248), ('ln', 3235), ('imperial', 3159), ('point', 3086), ('de', 3054), ('ranch', 3022), ('pas', 3016), ('park', 2935), ('e', 2885), ('grove', 2876), ('vermont', 2852), ('atlantic', 2786), ('willow', 2732), ('around', 2670), ('line', 2644), ('state', 2562), ('vehicle', 2499), ('sepulveda', 2456), ('pky', 2407), ('via', 2387), ('harbor', 2384), ('alameda', 2372), ('watt', 2298), ('riverside', 2288), ('rancho', 2250), ('view', 2240), ('slow', 2228), ('los', 2220), ('redwood', 2201), ('pacific', 2198), ('van', 2164), ('crenshaw', 2164), ('w', 2150), ('bernardino', 2144), ('expy', 2092), ('bus', 2086), ('n', 2078), ('cherry', 2071), ('california', 2042), ('florence', 2008), ('bay', 1976), ('university', 1966), ('diego', 1949), ('rosecrans', 1945), ('long', 1935), ('azusa', 1931), ('work', 1904), ('slauson', 1881), ('madison', 1872), ('brea', 1867), ('grant', 1858), ('western', 1849), ('recovery', 1846), ('telegraph', 1842), ('roadway', 1836), ('fe', 1827), ('foothill', 1824), ('king', 1809), ('cruz', 1806), ('college', 1788), ('sunset', 1751), ('amp', 1742), ('euclid', 1725), ('mesa', 1724), ('lincoln', 1718), ('capital', 1714), ('hacienda', 1688), ('florin', 1653), ('angeles', 1649), ('burbank', 1645), ('real', 1642), ('hard', 1638), ('macarthur', 1636), ('magnolia', 1586), ('coast', 1586), ('forest', 1578), ('airport', 1577), ('fremont', 1573), ('martin', 1514), ('olympic', 1499), ('cienega', 1496), ('monica', 1479), ('green', 1468), ('carpool', 1457), ('gabriel', 1434), ('normandie', 1434), ('hov', 1428), ('monte', 1416), ('whittier', 1405), ('mar', 1362), ('ana', 1359), ('bridge', 1354), ('wilmington', 1348), ('garfield', 1326), ('laurel', 1320), ('guadalupe', 1319), ('obstructed', 1318), ('luther', 1314), ('ventura', 1301), ('vernon', 1299), ('segundo', 1296), ('citrus', 1290), ('block', 1268), ('bellflower', 1259), ('pioneer', 1255), ('fernando', 1253), ('carson', 1252), ('part', 1252), ('something', 1251), ('fair', 1234), ('century', 1233), ('treasure', 1228), ('orange', 1225), ('auto', 1222), ('brg', 1204), ('fire', 1201), ('golden', 1195), ('stockton', 1195), ('jackson', 1190), ('obstruction', 1190), ('buena', 1180), ('anita', 1179), ('paramount', 1177), ('ramona', 1171), ('summit', 1167), ('antonio', 1161), ('culver', 1154), ('mill', 1149), ('firestone', 1133), ('avalon', 1131), ('mall', 1129), ('walnut', 1117), ('lakewood', 1115), ('brookhurst', 1112), ('adam', 1094), ('saratoga', 1086), ('winchester', 1084), ('island', 1074), ('sand', 1074), ('peck', 1065), ('balboa', 1056), ('artesia', 1047), ('highland', 1045), ('rosemead', 1045)]
